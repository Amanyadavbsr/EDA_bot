# %%
from config import Config

# %%
config = Config()

# %%
import logging
from logger_module import AppLogger

# %%
AppLogger(log_file='Bot.log',log_level=logging.DEBUG)
logger = AppLogger.get_logger(__name__)
logger.info('Application class-based logger reagy')
# Out:
# 16:36:03 | INFO     | Application class-based logger reagy

# %%
from event_type_module import EventType
from event_bus_module import EventBus
from event_module import Event

bus = EventBus()

# %%
bus.subscribe(EventType.TEST_EVENT, lambda event: logger.info(f"Received event: {event}"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 bus.subscribe(EventType.TEST_EVENT, lambda event: logger.info(f"Received event: {event}"))
#
# AttributeError: type object 'EventType' has no attribute 'TEST_EVENT'
